# %%
import cv2 
import pathlib
import os  
from imutils import paths
import matplotlib.pyplot as plt
preprocessed_folder = "Sachin_preprocessed"
inp_folder = "sachin"

if not os.path.exists(preprocessed_folder):
    os.makedirs(preprocessed_folder)

image_files = os.listdir("sachin")

for i, image in enumerate(paths.list_images(inp_folder)) :
    try:
        print(cv2.imread(image).shape)
    
    except:
        pass
# Out:
# (400, 400, 3)
# (540, 960, 3)
# (400, 800, 3)
# (315, 600, 3)
# (528, 640, 3)
# (448, 800, 3)
# (720, 1280, 3)
# (300, 225, 3)
# (645, 1170, 3)
# (960, 1280, 3)
# (404, 647, 3)
# (312, 624, 3)
# (431, 715, 3)
# (768, 1024, 3)
# (355, 628, 3)
# (595, 1024, 3)
# (513, 768, 3)
# (363, 647, 3)
# (127, 220, 3)
# (628, 1200, 3)
# (386, 427, 3)
# (720, 1280, 3)
# (343, 600, 3)
# (422, 759, 3)
# (606, 420, 3)
# (518, 485, 3)
# (431, 715, 3)
# (422, 759, 3)
# (685, 670, 3)
# (422, 759, 3)
# (375, 500, 3)
# (600, 900, 3)
# (768, 1024, 3)
# (440, 600, 3)
# (768, 1024, 3)
# (423, 306, 3)
# (513, 1100, 3)
# (832, 540, 3)
# (298, 640, 3)
# (473, 600, 3)
# (385, 594, 3)
# (428, 300, 3)
# (605, 806, 3)
# (488, 420, 3)
# (583, 875, 3)
# (1126, 768, 3)
# (192, 192, 3)
# (768, 1024, 3)
# (440, 660, 3)
# (440, 660, 3)
# (720, 1280, 3)
# (900, 900, 3)
# (292, 300, 3)
# (408, 612, 3)
# (1200, 721, 3)
# (540, 960, 3)
# (891, 670, 3)
# (250, 480, 3)
# (400, 600, 3)
# (448, 800, 3)
# (1556, 2400, 3)
# ...

# %%
image_path = list(paths.list_images(inp_folder))[5]
image_data = cv2.imread(image_path)
plt.imshow(image_data)
print(image_data.shape)
# Out:
# (528, 640, 3)

# %%
resized = cv2.resize(image_data, (250, 250))

plt.imshow(resized)
cv2.imwrite('fsa.jpg',resized)
resized.shape
# Out:
# (250, 250, 3)
